# %%
# %load_ext autoreload

# %%
# %autoreload 2

# %%
from plotutils import htmlbokehplot, htmlclassifiedplot
from utils import las2df, minmax_depth

# %%
lasfile = '../data/Torosa1.las'
df = las2df(lasfile)
mi,ma = minmax_depth(df, ['GR'])
df.head()
# Out:
#              BIT       CAL  DRHO        DTC         GR  NET  NPHI  PEF  POTA  \
# Depth
# 3460.851562  8.5  8.682764   NaN  61.528431  30.226101  0.0   NaN  NaN   NaN
# 3461.003906  8.5  8.673630   NaN  60.924686  30.030220  0.0   NaN  NaN   NaN
# 3461.156250  8.5  8.651960   NaN  62.153492  24.237159  0.0   NaN  NaN   NaN
# 3461.308594  8.5  8.661836   NaN  63.354270  22.113553  0.0   NaN  NaN   NaN
# 3461.460938  8.5  8.672555   NaN  64.474434  22.055748  0.0   NaN  NaN   NaN
#
#                  RESD     ...       MOBILITY  IC4  NC5  TGAS  NC4  C1  C3  \
# Depth                     ...
# 3460.851562  3.947122     ...            NaN  NaN  NaN   NaN  NaN NaN NaN
# 3461.003906  4.563832     ...            NaN  NaN  NaN   NaN  NaN NaN NaN
# 3461.156250  4.968863     ...            NaN  NaN  NaN   NaN  NaN NaN NaN
# 3461.308594  5.262069     ...            NaN  NaN  NaN   NaN  NaN NaN NaN
# 3461.460938  5.374542     ...            NaN  NaN  NaN   NaN  NaN NaN NaN
#
# ...

# %%
html = htmlbokehplot(df,mi,ma)

# %%
from IPython.core.display import display, HTML
display(HTML(html))
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>my plot</title>
#
#
#
#
#         <link rel="stylesheet" href="https://cdn.pydata.org/bokeh/release/bokeh-1.0.1.min.css" type="text/css" />
#
#
#
#         <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-1.0.1.min.js"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="feaecbbb-ca24-4b06-992b-3da43534cd4e"></div>
#
#
#
#
#
#         <script type="application/json" id="1249">
# ...

# %%
from importlib import reload

# %%
import plotutils

# %%
reload(plotutils)
# Out:
# <module 'plotutils' from '/home/gijs/Projects/lithograph-website/scripts/plotutils.py'>

# %%
htmlo = plotutils.htmlclassifiedplot(df,mi,ma)

# %%
display(HTML(htmlo))
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
#   <head>
#
#       <meta charset="utf-8">
#       <title>my plot</title>
#
#
#
#
#         <link rel="stylesheet" href="https://cdn.pydata.org/bokeh/release/bokeh-1.0.1.min.css" type="text/css" />
#
#
#
#         <script type="text/javascript" src="https://cdn.pydata.org/bokeh/release/bokeh-1.0.1.min.js"></script>
#         <script type="text/javascript">
#             Bokeh.set_log_level("info");
#         </script>
#
#
#
#
#   </head>
#
#
#   <body>
#
#
#
#
#
#
#               <div class="bk-root" id="4f13f6b9-cacf-482a-9f92-7804683e3d93"></div>
#
#
#
#
#
#         <script type="application/json" id="2144">
# ...

# %%
import ml

# %%
model = ml.load_model('../data/poseidon-model.dat')
# Out:
# /home/gijs/miniconda3/envs/lithograph/lib/python3.6/site-packages/sklearn/base.py:251: UserWarning: Trying to unpickle estimator LabelEncoder from version 0.19.2 when using version 0.20.0. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
arr = ml.xgb_predict(logs_df=df, model=model)

# %%
import matplotlib.pyplot as plt
plt.plot(df.DRHO,arr)

# %%
len(arr)
# Out:
# 8012

# %%
df.shape
# Out:
# (8012, 29)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of              BIT       CAL      DRHO        DTC          GR  NET  NPHI  \
# Depth
# 3460.851562  8.5  8.682764       NaN  61.528431   30.226101  0.0   NaN
# 3461.003906  8.5  8.673630       NaN  60.924686   30.030220  0.0   NaN
# 3461.156250  8.5  8.651960       NaN  62.153492   24.237159  0.0   NaN
# 3461.308594  8.5  8.661836       NaN  63.354270   22.113553  0.0   NaN
# 3461.460938  8.5  8.672555       NaN  64.474434   22.055748  0.0   NaN
# 3461.613281  8.5  8.683670       NaN  66.860968   22.621274  0.0   NaN
# 3461.765625  8.5  8.673398       NaN  69.676313   26.141210  0.0   NaN
# 3461.917969  8.5  8.673102       NaN  71.884049   28.986095  0.0   NaN
# 3462.070313  8.5  8.673364       NaN  72.225473   28.566836  0.0   NaN
# 3462.222657  8.5  8.683261       NaN  69.622653   28.104211  0.0   NaN
# 3462.375000  8.5  8.683556       NaN  65.334138   24.779175  0.0   NaN
# 3462.527344  8.5  8.677144       NaN  62.282870   19.776460  0.0   NaN
# ...
